# %% [markdown]
# # Effect of the Economical Environment on the Preferences of Car Makes a Consumer Purchases

# %% [markdown]
# ## Data Gathering

# %% [markdown]
# ### Data Grab For Price of Stock or Crypto

# %% [markdown]
# The packages are not pre installed on the servers and will need to be pip installed. Open a terminal on Coursera and Input line below:

# %% [markdown]
# https://pypi.org/project/yfinance/

# %% [markdown]
# - pip install pandas_datareader

# %% [markdown]
# - pip install yfinance

# %%
from pandas_datareader import data as pdr
import yfinance as yf
import pandas as pd

yf.pdr_override()  # <== that's all it takes :-)

# initialization
# Dates
start_date = "2021-01-01"
end_date = "2022-04-30"
# Stocks_Crypto
# "TSLA" -> Tesla, "F" -> Ford, "BTC" -> Bitcoin, "CL=F" -> Crude Oil
s_c = ["BTC-USD","TSLA","F"]
# The data set can be srunk down by calling out a frame or multiple ["Open","High","Low","Close","Adj Close","Volume"]
col = ["Open","Close"]

# Example code for pulling the stock price as a downloaded dataframe
# Example for bitcoin
# data = pdr.get_data_yahoo("BTC-USD", start="2020-01-01", end="2022-04-30")

# Loop through all of the desired stocks and pull the data from the yahoo finance API
for index, stock in enumerate(s_c):
    data = pdr.get_data_yahoo(stock, start=start_date, end=end_date)[col]
    for item in col:
        temp_text = stock + "_" + item
        #print(temp_text)
        data = data.rename(columns={item: temp_text})
    #print(data)
    print(stock, index)
    if index == 0:
        df_data = data
    else:
        df_data = pd.merge(df_data,data, on=['Date'], how='outer')

display(df_data)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# BTC-USD 0
# [*********************100%%**********************]  1 of 1 completed
# TSLA 1
# [*********************100%%**********************]  1 of 1 completed
# F 2
#             BTC-USD_Open  BTC-USD_Close   TSLA_Open  TSLA_Close  F_Open  \
# Date
# 2021-01-01  28994.009766   29374.152344         NaN         NaN     NaN
# 2021-01-02  29376.455078   32127.267578         NaN         NaN     NaN
# 2021-01-03  32129.408203   32782.023438         NaN         NaN     NaN
# 2021-01-04  32810.949219   31971.914062  239.820007  243.256668    8.81
# 2021-01-05  31977.041016   33992.429688  241.220001  245.036667    8.47
# ...                  ...            ...         ...         ...     ...
# 2022-04-25  39472.605469   40458.308594  326.323334  332.673340   14.91
# 2022-04-26  40448.421875   38117.460938  331.809998  292.140015   15.10
# 2022-04-27  38120.300781   39241.121094  299.526672  293.836670   14.79
# 2022-04-28  39241.429688   39773.828125  299.993347  292.503326   14.91
# 2022-04-29  39768.617188   38609.824219  300.750000  290.253326   14.59
#
#             F_Close
# Date
# 2021-01-01      NaN
# 2021-01-02      NaN
# 2021-01-03      NaN
# 2021-01-04     8.52
# 2021-01-05     8.65
# ...             ...
# 2022-04-25    15.19
# 2022-04-26    14.71
# 2022-04-27    14.85
# 2022-04-28    14.62
# 2022-04-29    14.16
#
# [484 rows x 6 columns]

# %% [markdown]
# ### Import Vehicle Fuel Economy Dataset

# %% [markdown]
# The dataset is available in the following website

# %% [markdown]
# https://www.fueleconomy.gov/feg/ws/#ft9

# %%
import pandas as pd

# %%
raw_fuel_economy_df = pd.read_csv("https://www.fueleconomy.gov/feg/epadata/fuel prices.csv", low_memory=False)
raw_fuel_economy_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 raw_fuel_economy_df = pd.read_csv("https://www.fueleconomy.gov/feg/epadata/fuel prices.csv", low_memory=False)
#       2 raw_fuel_economy_df.head()
#
# NameError: name 'pd' is not defined

# %%
raw_fuel_economy_df.shape
# Out:
# (46565, 84)

# %% [markdown]
# ### Opening Vehicle sales dataset

# %% [markdown]
# The dataset is available in the following website

# %% [markdown]
# https://www.kaggle.com/datasets/suraj520/car-sales-data

# %%
raw_car_sales_df = pd.read_csv("car_sales_data.csv")
raw_car_sales_df.head()
# Out:
#          Date      Salesperson   Customer Name Car Make  Car Model  Car Year  \
# 0  2022-08-01  Monica Moore MD     Mary Butler   Nissan     Altima      2018
# 1  2023-03-15     Roberto Rose  Richard Pierce   Nissan      F-150      2016
# 2  2023-04-29     Ashley Ramos    Sandra Moore     Ford      Civic      2016
# 3  2022-09-04   Patrick Harris    Johnny Scott     Ford     Altima      2013
# 4  2022-06-16       Eric Lopez   Vanessa Jones    Honda  Silverado      2022
#
#    Sale Price  Commission Rate  Commission Earned
# 0       15983         0.070495            1126.73
# 1       38474         0.134439            5172.40
# 2       33340         0.114536            3818.63
# 3       41937         0.092191            3866.20
# 4       20256         0.113490            2298.85

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# ### Imports

# %% [markdown]
# Imports that will be used for data manipulation

# %%
from pandas_datareader import data as pdr
import yfinance as yf
import pandas as pd

# %%
# copy the datset to keep the origanl
car_sales_df = raw_car_sales_df.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 # copy the datset to keep the origanl
# ----> 2 car_sales_df = raw_car_sales_df.copy()
#
# NameError: name 'raw_car_sales_df' is not defined

# %%
# put dates in datetime format and get the date of the first and last cars sold
car_sales_df["Date"] = pd.to_datetime(car_sales_df["Date"], format="%Y-%m-%d")
sales_start_date = car_sales_df["Date"].min().strftime("%Y-%m-%d")
sales_end_date = car_sales_df["Date"].max().strftime("%Y-%m-%d")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [11], line 2
#       1 # put dates in datetime format and get the date of the first and last cars sold
# ----> 2 car_sales_df["Date"] = pd.to_datetime(car_sales_df["Date"], format="%Y%m%d")
#       3 sales_start_date = car_sales_df["Date"].min().strftime("%Y-%m-%d")
#       4 sales_end_date = car_sales_df["Date"].max().strftime("%Y-%m-%d")
#
# File ~/venv/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1108, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1106             result = arg.tz_localize("utc")
#    1107 elif isinstance(arg, ABCSeries):
# -> 1108     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1109     if not cache_array.empty:
#    1110         result = arg.map(cache_array)
#
# File ~/venv/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:254, in _maybe_cache(arg, format, cache, convert_listlike)
#     252 unique_dates = unique(arg)
#     253 if len(unique_dates) < len(arg):
# --> 254     cache_dates = convert_listlike(unique_dates, format)
#     255     # GH#45319
#     256     try:
#
# File ~/venv/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:488, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     486 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     487 if format is not None and format != "mixed":
# --> 488     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     490 result, tz_parsed = objects_to_datetime64ns(
#     491     arg,
#     492     dayfirst=dayfirst,
#    (...)
#     496     allow_object=True,
#     497 )
#     499 if tz_parsed is not None:
#     500     # We can take a shortcut since the datetime64 numpy array
#     501     # is in UTC
#
# File ~/venv/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:519, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     508 def _array_strptime_with_fallback(
#     509     arg,
#     510     name,
#    (...)
#     514     errors: str,
#     515 ) -> Index:
#     516     """
#     517     Call array_strptime, with fallback behavior depending on 'errors'.
#     518     """
# --> 519     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     520     if any(tz is not None for tz in timezones):
#     521         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File strptime.pyx:534, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:355, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "2022-08-01" doesn't match format "%Y%m%d", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
# Create a function to get the data from Yahoo Finance API
def get_market_data (ticker, start_date, end_date):
    
    yf.pdr_override()  # <== that's all it takes :-)

    # download dataframe
    # This is the yahoo name for oil Crude Oil Oct 23 (CL=F)
    df = pdr.get_data_yahoo(ticker, start=start_date, end=end_date)
    
    return df.reset_index()

# %%
# Get the financial information about economical and crypto data

# Crude Oil prices dataframe
crude_oil_df = get_market_data("CL=F", sales_start_date, sales_end_date)

# Bitcoin Price dataframe
BTC_df = get_market_data("BTC-USD", sales_start_date, sales_end_date)

# SP500 dataframe
SP500_df = get_market_data("^GSPC", sales_start_date, sales_end_date)

# Dow Jones Industrial dataframe
DJI_df = get_market_data("^DJI", sales_start_date, sales_end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=70337ec4-2598-4a20-9e82-38b4f4c44d51' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
